# %%
import pandas as pd

# %%
ana=pd.read_csv("naiades/Analyses.CSV", on_bad_lines='warn', delimiter=';')
# Out:
# /tmp/ipykernel_16486/3051973136.py:1: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   ana=pd.read_csv("naiades/Analyses.CSV", on_bad_lines='warn', delimiter=';')

# %%
ana.head()
# Out:
#    CdStationMesureEauxSurface          LbStationMesureEauxSurface  CdSupport  \
# 0                     2001046  LE MUHLBACH DE SCHOENAU À SCHOENAU          3
# 1                     2001046  LE MUHLBACH DE SCHOENAU À SCHOENAU          3
# 2                     2001046  LE MUHLBACH DE SCHOENAU À SCHOENAU          3
# 3                     2001046  LE MUHLBACH DE SCHOENAU À SCHOENAU          3
# 4                     2001046  LE MUHLBACH DE SCHOENAU À SCHOENAU          3
#
#   LbSupport  CdFractionAnalysee LbFractionAnalysee  CdPrelevement    DatePrel  \
# 0       Eau                  23          Eau brute        4548590  2016-11-28
# 1       Eau                  23          Eau brute        4548590  2016-11-28
# 2       Eau                  23          Eau brute        4548590  2016-11-28
# 3       Eau                  23          Eau brute        4548590  2016-11-28
# 4       Eau                  23          Eau brute        4548590  2016-11-28
#
# ...

# %%
ana['LbLongParamètre'].unique()
# Out:
# array(["Température de l'Eau", 'pH', 'Conductivité', 'Oxygène dissous',
#        'Matières en suspension', 'DBO5', 'D.C.O.', 'Azote Kjeldahl',
#        'Phosphore total', 'Taux de saturation en O2', 'Azote global',
#        'Azote organique', 'Dureté totale', 'Couleur mesurée', 'Ammonium',
#        'Nitrites', 'Nitrates', 'Orthophosphates', 'Carbone Organique',
#        'Bicarbonates', 'Carbonates', 'Chlorures', 'Sulfates', 'Potassium',
#        'Magnésium', 'Calcium', 'Sodium', 'Somme cations de const.',
#        'Somme anions de const.', 'Chloroforme', 'Dibromochloromethane',
#        'Dichloroéthane 11', 'Dichloroéthane 12', 'Dichloroéthène 11',
#        '1,2-Dichlorethene', 'Dichlorobenzène 13', 'Dichlorobenzene 12',
#        'Dichlorobenzène 14', 'Dichlorométhane', 'Fréon 113',
#        'Tétrachloréthane-1,1,2,2', 'Tétrachloroéthylène',
#        'Tétrachl.Carbone', 'Trichlorobenzène-1,2,4',
#        'Trichloréthane-1,1,1', 'Trichloréthane-1,1,2', 'Trichloréthylène',
# ...

# %%
pd.set_option('display.max_rows', 500)

# %%
uniq=ana.groupby('LbLongParamètre')['CdPrelevement'].nunique()

# %%
percent=(uniq/(ana['CdPrelevement'].nunique())).sort_values()

# %%
percent.head()
# Out:
# LbLongParamètre
# Fenoprofen             0.000015
# Dinosèbe               0.000015
# Triglyme               0.000015
# Pentachloroanisole     0.000015
# Dichloroaniline-2,5    0.000074
# Name: CdPrelevement, dtype: float64

# %% [raw]
# percent

# %%
subana=ana[['LbLongParamètre','CdPrelevement']]
subana

# %%
df_pivot = ana.pivot(index='CdPrelevement', columns='LbLongParamètre', values='RsAna')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df_pivot = ana.pivot(index='CdPrelevement', columns='LbLongParamètre', values='RsAna')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:9339, in DataFrame.pivot(self, columns, index, values)
#    9332 @Substitution("")
#    9333 @Appender(_shared_docs["pivot"])
#    9334 def pivot(
#    9335     self, *, columns, index=lib.no_default, values=lib.no_default
#    9336 ) -> DataFrame:
#    9337     from pandas.core.reshape.pivot import pivot
# -> 9339     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/pivot.py:570, in pivot(data, columns, index, values)
#     566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# ...

# %%
duplicates = ana[ana.duplicated(subset=['CdPrelevement', 'LbLongParamètre'], keep=False)]

print(duplicates)
# Out:
#         CdStationMesureEauxSurface LbStationMesureEauxSurface  CdSupport  \
# 528                        2001050           LE RHIN À RHINAU          3
# 725                        2001050           LE RHIN À RHINAU          3
# 1190                       2001050           LE RHIN À RHINAU          3
# 1222                       2001050           LE RHIN À RHINAU          3
# 1224                       2001050           LE RHIN À RHINAU          3
# ...                            ...                        ...        ...
# 359375                     2098800       L'EICHEL À OERMINGEN          3
# 359383                     2098800       L'EICHEL À OERMINGEN          3
# 359400                     2098800       L'EICHEL À OERMINGEN          3
# 359418                     2098800       L'EICHEL À OERMINGEN          3
# 359436                     2098800       L'EICHEL À OERMINGEN          3
#
#        LbSupport  CdFractionAnalysee  \
# 528          Eau                  23
# ...

# %%
ana.loc[ana['RsAna'].isnull()]
# Out:
# Empty DataFrame
# Columns: [CdStationMesureEauxSurface, LbStationMesureEauxSurface, CdSupport, LbSupport, CdFractionAnalysee, LbFractionAnalysee, CdPrelevement, DatePrel, HeurePrel, DateAna, HeureAna, CdParametre, LbLongParamètre, RsAna, CdUniteMesure, SymUniteMesure, CdRqAna, MnemoRqAna, CdInsituAna, LbInsituAna, ProfondeurPrel, CdDifficulteAna, MnemoDifficulteAna, LdAna, LqAna, LsAna, IncertAna, CdMetFractionnement, NomMetFractionnement, CdMethode, NomMethode, RdtExtraction, CdMethodeExtraction, NomMethodeExtraction, CdAccreAna, MnemoAccredAna, AgreAna, CdStatutAna, MnemoStatutAna, CdQualAna, LbQualAna, CommentairesAna, ComResultatAna, CdRdd, NomRdd, CdProducteur, NomProducteur, CdPreleveur, NomPreleveur, CdLaboratoire, NomLaboratoire]
# Index: []
#
# [0 rows x 51 columns]

# %%
ana.iloc[[528]]
# Out:
#      CdStationMesureEauxSurface LbStationMesureEauxSurface  CdSupport  \
# 528                     2001050           LE RHIN À RHINAU          3
#
#     LbSupport  CdFractionAnalysee LbFractionAnalysee  CdPrelevement  \
# 528       Eau                  23          Eau brute        4548257
#
#        DatePrel HeurePrel     DateAna  ... CommentairesAna  ComResultatAna  \
# 528  2016-12-07  09:25:00  2016-12-08  ...             NaN             NaN
#
#           CdRdd                                             NomRdd  \
# 528  0200000012  Suivi international de la qualité des eaux du ...
#
#        CdProducteur               NomProducteur   CdPreleveur  \
# 528  18570301400018  AGENCE DE L'EAU RHIN-MEUSE  4.452360e+13
#
#                                  NomPreleveur  CdLaboratoire  \
# 528  CENTRE D'ANALYSES ET DE RECHERCHES - CAR   4.105453e+13
#
#                                         NomLaboratoire
# 528  CARSO Laboratoire Santé Environnement Hygiène ...
#
# [1 rows x 51 columns]
