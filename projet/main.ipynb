# %%
import pandas as pd
import geopandas as gpd
import shapely.geometry as geom
import os


pd.set_option('display.max_columns', None)

nrows=1000

# %%
dst = pd.read_csv("stations_hb.csv.zst",sep=';',escapechar = '\\', nrows=nrows)
dhb = pd.read_csv("donnees_hydrobio.csv.zst",sep=',',escapechar = '\\', nrows=nrows)
dpc = pd.read_csv("donnees_physicochimie.csv.zst",sep=',',escapechar = '\\', nrows=nrows)

# %%
dst
# Out:
#      CdStationMesureEauxSurface                   LbStationMesureEauxSurface  \
# 0                       1000477                      LA SLACK À RINXENT (62)
# 1                       1000602              COLOGNE à BUIRE COURCELLES (80)
# 2                       1000605                      L'OMIGNON À DEVISE (80)
# 3                       1001122          L'HELPE MAJEURE À EPPE SAUVAGE (59)
# 4                       1001131              HELPE MINEURE à GRAND FAYT (59)
# ..                          ...                                          ...
# 995                     2100150         LA SARRE À GROSBLIEDERSTROFF (AMONT)
# 996                     2100185  LE RUISSEAU DE LIXING À LIXING-LES-ROUHLING
# 997                     2100600                      LA HORN À LIEDERSCHIEDT
# 998                     2100610                 LE SCHWARZBACH À WALSCHBRONN
# 999                     2100620                 LE BREIDENBACH À BREIDENBACH
#
#      DurStationMesureEauxSurface  CoordXStationMesureEauxSurface  \
# 0                            NaN                       610228.78
# 1                            NaN                       700318.40
# 2                            NaN                       700279.85
# 3                            NaN                       784224.69
# 4                            NaN                       757716.99
# ..                           ...                             ...
# 995                          8.0                       994763.00
# 996                          0.0                       990371.00
# 997                          4.0                      1026267.00
# 998                          8.0                      1027273.00
# 999                          0.0                      1022560.00
#
#      CoordYStationMesureEauxSurface  CdProjStationMesureEauxSurface  \
# 0                        7078879.90                              26
# 1                        6980033.60                              26
# 2                        6973284.26                              26
# 3                        7002720.08                              26
# 4                        7002035.12                              26
# ..                              ...                             ...
# 995                      6901619.00                              26
# 996                      6902353.00                              26
# 997                      6901181.00                              26
# 998                      6903335.00                              26
# 999                      6901478.00                              26
#
#       LibelleProjection  CodeCommune            LbCommune  CodeDepartement  \
# 0    RGF93 / Lambert 93        62711              RINXENT               62
# 1    RGF93 / Lambert 93        80150     BUIRE-COURCELLES               80
# 2    RGF93 / Lambert 93        80239               DEVISE               80
# 3    RGF93 / Lambert 93        59198         EPPE-SAUVAGE               59
# 4    RGF93 / Lambert 93        59270           GRAND-FAYT               59
# ..                  ...          ...                  ...              ...
# 995  RGF93 / Lambert 93        57260    GROSBLIEDERSTROFF               57
# 996  RGF93 / Lambert 93        57408  LIXING-LÈS-ROUHLING               57
# 997  RGF93 / Lambert 93        57402        LIEDERSCHIEDT               57
# 998  RGF93 / Lambert 93        57741          WALSCHBRONN               57
# 999  RGF93 / Lambert 93        57108          BREIDENBACH               57
#
#      ... DateMAJInfosStationMesureEauxSurface  \
# 0    ...                  2015-12-14 00:00:00
# 1    ...                  2015-12-14 00:00:00
# 2    ...                  2015-12-14 00:00:00
# 3    ...                  2011-06-07 00:00:00
# 4    ...                  2016-01-06 00:00:00
# ..   ...                                  ...
# 995  ...                  2019-03-26 00:00:00
# 996  ...                  2018-10-11 00:00:00
# 997  ...                  2017-10-25 00:00:00
# 998  ...                  2014-09-03 00:00:00
# 999  ...                  2014-09-03 00:00:00
#
#      FinaliteStationMesureEauxSurface  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 995                               NaN
# 996                               NaN
# 997                               NaN
# 998                               NaN
# 999                               NaN
#
#                  LocPreciseStationMesureEauxSurface  \
# 0    Lieu-dit Ferme du Château. La Planche du Devin
# 1                     MOULIN DE BINARD PONT D 194 E
# 2                                 ROUTE DE L'EGLISE
# 3                                   PONT DE LA D119
# 4                                     ANCIEN MOULIN
# ..                                              ...
# 995            LA SARRE À GROSBLIEDERSTROFF (AMONT)
# 996     LE RUISSEAU DE LIXING À LIXING-LES-ROUHLING
# 997                         LA HORN À LIEDERSCHIEDT
# 998                    LE SCHWARZBACH À WALSCHBRONN
# 999                    LE BREIDENBACH À BREIDENBACH
#
#     CodeNatureStationMesureEauxSurface LibelleNatureStationMesureEauxSurface  \
# 0                                    M            Station de mesure Manuelle
# 1                                    M            Station de mesure Manuelle
# 2                                    M            Station de mesure Manuelle
# 3                                    M            Station de mesure Manuelle
# 4                                    M            Station de mesure Manuelle
# ..                                 ...                                   ...
# 995                                NaN                                   NaN
# 996                                NaN                                   NaN
# 997                                NaN                                   NaN
# 998                                NaN                                   NaN
# 999                                NaN                                   NaN
#
#     AltitudePointCaracteritisque PkPointTronconEntiteHydroPrincipale  \
# 0                            0.0                              980.48
# 1                            0.0                              992.58
# 2                            0.0                              993.69
# 3                          183.0                              947.01
# 4                            0.0                              987.60
# ..                           ...                                 ...
# 995                        193.0                                 NaN
# 996                        231.0                                 NaN
# 997                        258.0                                 NaN
# 998                        259.0                                 NaN
# 999                        269.0                                 NaN
#
#     PremierMoisAnneeEtiage SuperficieBassinVersantReel  \
# 0                      6.0                         NaN
# 1                      6.0                         NaN
# 2                      6.0                         NaN
# 3                      6.0                         NaN
# 4                      6.0                         NaN
# ..                     ...                         ...
# 995                    NaN                         NaN
# 996                    NaN                         NaN
# 997                    NaN                         NaN
# 998                    NaN                         NaN
# 999                    NaN                         NaN
#
#     SuperficieBassinVersantTopo
# 0                           0.0
# 1                           0.0
# 2                           0.0
# 3                           NaN
# 4                           0.0
# ..                          ...
# 995                      1734.1
# 996                         NaN
# 997                        95.5
# 998                         NaN
# 999                         NaN
#
# [1000 rows x 39 columns]

# %%
crs_lambert = 'PROJCS["RGF_1993_Lambert_93",GEOGCS["GCS_RGF_1993",DATUM["D_RGF_1993",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Lambert_Conformal_Conic"],PARAMETER["False_Easting",700000.0],PARAMETER["False_Northing",6600000.0],PARAMETER["Central_Meridian",3.0],PARAMETER["Standard_Parallel_1",49.0],PARAMETER["Standard_Parallel_2",44.0],PARAMETER["Latitude_Of_Origin",46.5],UNIT["Meter",1.0]]'
x_col = 'CoordXStationMesureEauxSurface'
y_col = 'CoordYStationMesureEauxSurface'

carto_i2m2 = gpd.GeoDataFrame(dst,crs=crs_lambert ,
                        geometry = gpd.GeoSeries(dst.agg(lambda x:geom.Point(x.loc[x_col],x.loc[y_col])  ,axis=1)))

# %%
her = gpd.read_file("Hydroecoregion1-shp/Hydroecoregion1.shp")

# %%
her.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c360b1ce7c002aa22b1ad60113a32e68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c360b1ce7c002aa22b1ad60113a32e68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c360b1ce7c002aa22b1ad60113a32e68 = L.map(
#                 &quot;map_c360b1ce7c002aa22b1ad60113a32e68&quot;,
#                 {
#                     center: [46.229237655148324, 2.382543487339459],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c360b1ce7c002aa22b1ad60113a32e68);
#
#
#
#
#
#             var tile_layer_6a1debb0b2d6c3d31007c8ce3f7ac801 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a1debb0b2d6c3d31007c8ce3f7ac801.addTo(map_c360b1ce7c002aa22b1ad60113a32e68);
#
#
#             map_c360b1ce7c002aa22b1ad60113a32e68.fitBounds(
#                 [[41.368824225802044, -4.7949497286449825], [51.089651084494605, 9.5600367033239]],
#                 {}
#             );
#
#
#         function geo_json_f46a54acfecddaf4493dc40174899023_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f46a54acfecddaf4493dc40174899023_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f46a54acfecddaf4493dc40174899023_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f46a54acfecddaf4493dc40174899023_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f46a54acfecddaf4493dc40174899023_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f46a54acfecddaf4493dc40174899023.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f46a54acfecddaf4493dc40174899023_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f46a54acfecddaf4493dc40174899023 = L.geoJson(null, {
#                 onEachFeature: geo_json_f46a54acfecddaf4493dc40174899023_onEachFeature,
#
#                 style: geo_json_f46a54acfecddaf4493dc40174899023_styler,
#                 pointToLayer: geo_json_f46a54acfecddaf4493dc40174899023_pointToLayer,
#         });
#
#         function geo_json_f46a54acfecddaf4493dc40174899023_add (data) {
#             geo_json_f46a54acfecddaf4493dc40174899023
#                 .addData(data);
#         }
#             geo_json_f46a54acfecddaf4493dc40174899023_add({&quot;bbox&quot;: [-4.7949497286449825, 41.368824225802044, 9.5600367033239, 51.089651084494605], &quot;features&quot;: [{&quot;bbox&quot;: [8.54345568102667, 41.368824225802044, 9.5600367033239, 43.01056930218558], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[9.433192083613715, 43.00467781178711], [9.435698728860494, 42.99999222466892], [9.443625052198316, 42.9955143099137], [9.446280794070498, 42.99194601676021], [9.453715154998704, 42.98976404777328], [9.456566996579705, 42.987887181427226], [9.463371228317671, 42.98687402149207], [9.46143157419669, 42.98361190239381], [9.459854553696255, 42.97692502772555], [9.454926052999816, 42.974421480062674], [9.455768544039088, 42.96871882664394], [9.455295099182507, 42.96479067191348], [9.4533566

# %%
carto_i2m2.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52d014a825b4554bf5df037ee89deef3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52d014a825b4554bf5df037ee89deef3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52d014a825b4554bf5df037ee89deef3 = L.map(
#                 &quot;map_52d014a825b4554bf5df037ee89deef3&quot;,
#                 {
#                     center: [49.18941560445239, 4.92885254817995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_52d014a825b4554bf5df037ee89deef3);
#
#
#
#
#
#             var tile_layer_30a42d7a5b0e92240abdec00c56dd46c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30a42d7a5b0e92240abdec00c56dd46c.addTo(map_52d014a825b4554bf5df037ee89deef3);
#
#
#             map_52d014a825b4554bf5df037ee89deef3.fitBounds(
#                 [[47.43434413252999, 1.6274505771302692], [50.944487076374784, 8.230254519229632]],
#                 {}
#             );
#
#
#         function geo_json_2f7fef17d7fdfd12055a3bf0bc652536_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_2f7fef17d7fdfd12055a3bf0bc652536_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_2f7fef17d7fdfd12055a3bf0bc652536_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_2f7fef17d7fdfd12055a3bf0bc652536_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_2f7fef17d7fdfd12055a3bf0bc652536_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_2f7fef17d7fdfd12055a3bf0bc652536.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_2f7fef17d7fdfd12055a3bf0bc652536_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_2f7fef17d7fdfd12055a3bf0bc652536 = L.geoJson(null, {
#                 onEachFeature: geo_json_2f7fef17d7fdfd12055a3bf0bc652536_onEachFeature,
#
#                 style: geo_json_2f7fef17d7fdfd12055a3bf0bc652536_styler,
#                 pointToLayer: geo_json_2f7fef17d7fdfd12055a3bf0bc652536_pointToLayer,
#         });
#
#         function geo_json_2f7fef17d7fdfd12055a3bf0bc652536_add (data) {
#             geo_json_2f7fef17d7fdfd12055a3bf0bc652536
#                 .addData(data);
#         }
#             geo_json_2f7fef17d7fdfd12055a3bf0bc652536_add({&quot;bbox&quot;: [1.6274505771302692, 47.43434413252999, 8.230254519229632, 50.944487076374784], &quot;features&quot;: [{&quot;bbox&quot;: [1.7290146526364214, 50.79989047699567, 1.7290146526364214, 50.79989047699567], &quot;geometry&quot;: {&quot;coordinates&quot;: [1.7290146526364214, 50.79989047699567], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;AltitudePointCaracteritisque&quot;: 0.0, &quot;CdBassinDCE&quot;: null, &quot;CdCoursdEau&quot;: &quot;E5100570&quot;, &quot;CdEuBassinDCE&quot;: null, &quot;CdEuMasseDEau&quot;: null, &quot;CdEuSsBassinDCEAdmin&quot;: null, &quot;CdMasseDEau&quot;: null, &quot;CdProjStationMesureEauxSurface&quot;: 26, &quot;CdStationMesureEauxSurface&quot;: 10004

# %%
dhb
# Out:
#      Unnamed: 0  CdStationMesureEauxSurface        LbStationMesureEauxSurface  \
# 0             0                     2000990          LE LERTZBACH À HEGENHEIM
# 1             1                     2001000           L'AUGRABEN À BARTENHEIM
# 2             2                     2001000           L'AUGRABEN À BARTENHEIM
# 3             3                     2001000           L'AUGRABEN À BARTENHEIM
# 4             4                     2001025           LE RIEDGRABEN À LANDSER
# ..          ...                         ...                               ...
# 995         995                     5068645               Le Mars au Vaulmier
# 996         996                     5068645               Le Mars au Vaulmier
# 997         997                     5068650   La Triouzoune en aval de Neuvic
# 998         998                     5068650   La Triouzoune en aval de Neuvic
# 999         999                     5068660  La Sumène au niveau de Bassignac
#
#      CdPointEauxSurf DateDebutOperationPrelBio  CdSupport  \
# 0                  1                2010-07-20         13
# 1                  2                2010-09-20         13
# 2                  2                2011-08-03         13
# 3                  2                2012-08-16         13
# 4                  5                2010-07-20         13
# ..               ...                       ...        ...
# 995              700                2011-09-29         13
# 996              700                2012-07-31         13
# 997              700                2011-06-23         13
# 998              700                2012-10-24         13
# 999              700                2010-08-31         13
#
#                        LbSupport DtProdResultatBiologique  \
# 0    Macroinvertébrés aquatiques                      NaN
# 1    Macroinvertébrés aquatiques                      NaN
# 2    Macroinvertébrés aquatiques                      NaN
# 3    Macroinvertébrés aquatiques                      NaN
# 4    Macroinvertébrés aquatiques                      NaN
# ..                           ...                      ...
# 995  Macroinvertébrés aquatiques               2018-06-14
# 996  Macroinvertébrés aquatiques               2018-06-14
# 997  Macroinvertébrés aquatiques               2018-06-14
# 998  Macroinvertébrés aquatiques               2018-06-14
# 999  Macroinvertébrés aquatiques               2018-06-14
#
#      CdParametreResultatBiologique                          LbLongParametre  \
# 0                             7613  Indice Invertébrés Multimétrique (I2M2)
# 1                             7613  Indice Invertébrés Multimétrique (I2M2)
# 2                             7613  Indice Invertébrés Multimétrique (I2M2)
# 3                             7613  Indice Invertébrés Multimétrique (I2M2)
# 4                             7613  Indice Invertébrés Multimétrique (I2M2)
# ..                             ...                                      ...
# 995                           7613  Indice Invertébrés Multimétrique (I2M2)
# 996                           7613  Indice Invertébrés Multimétrique (I2M2)
# 997                           7613  Indice Invertébrés Multimétrique (I2M2)
# 998                           7613  Indice Invertébrés Multimétrique (I2M2)
# 999                           7613  Indice Invertébrés Multimétrique (I2M2)
#
#      ...  CdUniteMesure SymUniteMesure CdRqIndiceResultatBiologique  \
# 0    ...              X              X                            1
# 1    ...              X              X                            1
# 2    ...              X              X                            1
# 3    ...              X              X                            1
# 4    ...              X              X                            1
# ..   ...            ...            ...                          ...
# 995  ...              X              X                            1
# 996  ...              X              X                            1
# 997  ...              X              X                            1
# 998  ...              X              X                            1
# 999  ...              X              X                            1
#
#                                             MnemoRqAna   CdMethEval  \
# 0    Résultat > seuil de quantification et < au seu...          NaN
# 1    Résultat > seuil de quantification et < au seu...          NaN
# 2    Résultat > seuil de quantification et < au seu...          NaN
# 3    Résultat > seuil de quantification et < au seu...          NaN
# 4    Résultat > seuil de quantification et < au seu...          NaN
# ..                                                 ...          ...
# 995  Résultat > seuil de quantification et < au seu...  I2M2_v1.0.3
# 996  Résultat > seuil de quantification et < au seu...  I2M2_v1.0.3
# 997  Résultat > seuil de quantification et < au seu...  I2M2_v1.0.3
# 998  Résultat > seuil de quantification et < au seu...  I2M2_v1.0.3
# 999  Résultat > seuil de quantification et < au seu...  I2M2_v1.0.3
#
#     RefOperationPrelBio    CdProducteur                  NomProducteur  \
# 0               1814647  18570301400018     AGENCE DE L'EAU RHIN MEUSE
# 1               1814648  18570301400018     AGENCE DE L'EAU RHIN MEUSE
# 2               2148304  18570301400018     AGENCE DE L'EAU RHIN MEUSE
# 3               2147990  18570301400018     AGENCE DE L'EAU RHIN MEUSE
# 4               1814649  18570301400018     AGENCE DE L'EAU RHIN MEUSE
# ..                  ...             ...                            ...
# 995             1621721  18310006400033  AGENCE DE L'EAU ADOUR GARONNE
# 996             1618504  18310006400033  AGENCE DE L'EAU ADOUR GARONNE
# 997             1622511  18310006400033  AGENCE DE L'EAU ADOUR GARONNE
# 998             1618403  18310006400033  AGENCE DE L'EAU ADOUR GARONNE
# 999             1624638  18310006400033  AGENCE DE L'EAU ADOUR GARONNE
#
#     CdAccredRsIndiceResultatBiologique  MnAccredRsIndiceResultatBiologique
# 0                                  0.0                             Inconnu
# 1                                  0.0                             Inconnu
# 2                                  0.0                             Inconnu
# 3                                  0.0                             Inconnu
# 4                                  0.0                             Inconnu
# ..                                 ...                                 ...
# 995                                0.0                             Inconnu
# 996                                0.0                             Inconnu
# 997                                0.0                             Inconnu
# 998                                0.0                             Inconnu
# 999                                0.0                             Inconnu
#
# [1000 rows x 21 columns]

# %%
dpc
# Out:
#      CdStationMesureEauxSurface                   LbStationMesureEauxSurface  \
# 0                       5005600                  La Béronne en aval de Melle
# 1                       5200115           Le Laurhibar à Saint Jean le Vieux
# 2                       5001800  L'Arnoult en amont de Pont l'Abbé d'Arnoult
# 3                       5001800  L'Arnoult en amont de Pont l'Abbé d'Arnoult
# 4                       5001800  L'Arnoult en amont de Pont l'Abbé d'Arnoult
# ..                          ...                                          ...
# 995                     5011640           Le Condéon à Barbezieux St Hilaire
# 996                     5011640           Le Condéon à Barbezieux St Hilaire
# 997                     5011640           Le Condéon à Barbezieux St Hilaire
# 998                     5011640           Le Condéon à Barbezieux St Hilaire
# 999                     5011640           Le Condéon à Barbezieux St Hilaire
#
#      CdSupport LbSupport  CdFractionAnalysee LbFractionAnalysee  \
# 0            3       Eau                  23          Eau brute
# 1            3       Eau                  23          Eau brute
# 2            3       Eau                  23          Eau brute
# 3            3       Eau                  23          Eau brute
# 4            3       Eau                  23          Eau brute
# ..         ...       ...                 ...                ...
# 995          3       Eau                  23          Eau brute
# 996          3       Eau                  23          Eau brute
# 997          3       Eau                  23          Eau brute
# 998          3       Eau                  23          Eau brute
# 999          3       Eau                  23          Eau brute
#
#      CdPrelevement    DatePrel HeurePrel  CdParametre  ... CommentairesAna  \
# 0           200561  2005-07-06  10:55:00         1305  ...             NaN
# 1           203218  2005-09-28  11:15:00         1313  ...             NaN
# 2           198487  2005-01-19  15:00:00         1301  ...             NaN
# 3           198487  2005-01-19  15:00:00         1302  ...             NaN
# 4           198487  2005-01-19  15:00:00         1303  ...             NaN
# ..             ...         ...       ...          ...  ...             ...
# 995         204177  2005-04-20  16:45:00         1311  ...             NaN
# 996         204177  2005-04-20  16:45:00         1312  ...             NaN
# 997         204177  2005-04-20  16:45:00         1313  ...             NaN
# 998         204177  2005-04-20  16:45:00         1319  ...             NaN
# 999         204177  2005-04-20  16:45:00         1350  ...             NaN
#
#      ComResultatAna        CdRdd  \
# 0               NaN  400000779.0
# 1               NaN  500000249.0
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# ..              ...          ...
# 995             NaN  500000116.0
# 996             NaN  500000116.0
# 997             NaN  500000116.0
# 998             NaN  500000116.0
# 999             NaN  500000116.0
#
#                                                 NomRdd    CdProducteur  \
# 0    Réseau de suivi de la qualité des eaux superfi...  25160178700053
# 1    Réseau de suivi de la qualité des eaux superfi...  18310006400033
# 2                                                  NaN  18310006400033
# 3                                                  NaN  18310006400033
# 4                                                  NaN  18310006400033
# ..                                                 ...             ...
# 995  Réseau Complémentaire Départemental de suivi d...  25160178700053
# 996  Réseau Complémentaire Départemental de suivi d...  25160178700053
# 997  Réseau Complémentaire Départemental de suivi d...  25160178700053
# 998  Réseau Complémentaire Départemental de suivi d...  25160178700053
# 999  Réseau Complémentaire Départemental de suivi d...  25160178700053
#
#                                          NomProducteur     CdPreleveur  \
# 0    ETABLISSEMENT PUBLIC TERRITORIAL DE BASSIN CHA...  22790001600014
# 1                        AGENCE DE L'EAU ADOUR GARONNE  22640001800066
# 2                        AGENCE DE L'EAU ADOUR GARONNE  18310006400033
# 3                        AGENCE DE L'EAU ADOUR GARONNE  18310006400033
# 4                        AGENCE DE L'EAU ADOUR GARONNE  18310006400033
# ..                                                 ...             ...
# 995  ETABLISSEMENT PUBLIC TERRITORIAL DE BASSIN CHA...  22160001800016
# 996  ETABLISSEMENT PUBLIC TERRITORIAL DE BASSIN CHA...  22160001800016
# 997  ETABLISSEMENT PUBLIC TERRITORIAL DE BASSIN CHA...  22160001800016
# 998  ETABLISSEMENT PUBLIC TERRITORIAL DE BASSIN CHA...  22160001800016
# 999  ETABLISSEMENT PUBLIC TERRITORIAL DE BASSIN CHA...  22160001800016
#
#                                           NomPreleveur   CdLaboratoire  \
# 0                          DEPARTEMENT DES DEUX SEVRES             379
# 1    DEPARTEMENT DES PYRENEES ATLANTIQUES - CENTR R...  22640001800066
# 2                        AGENCE DE L'EAU ADOUR GARONNE  18310006400033
# 3                        AGENCE DE L'EAU ADOUR GARONNE  18310006400033
# 4                        AGENCE DE L'EAU ADOUR GARONNE  18310006400033
# ..                                                 ...             ...
# 995                         DEPARTEMENT DE LA CHARENTE  22160001800016
# 996                         DEPARTEMENT DE LA CHARENTE  22160001800016
# 997                         DEPARTEMENT DE LA CHARENTE  22160001800545
# 998                         DEPARTEMENT DE LA CHARENTE  22160001800545
# 999                         DEPARTEMENT DE LA CHARENTE  22160001800545
#
#                                         NomLaboratoire
# 0    Direction Départementale de l'Agriculture et d...
# 1    DEPARTEMENT DES PYRENEES ATLANTIQUES - CENTR R...
# 2                        AGENCE DE L'EAU ADOUR GARONNE
# 3                        AGENCE DE L'EAU ADOUR GARONNE
# 4                        AGENCE DE L'EAU ADOUR GARONNE
# ..                                                 ...
# 995                         DEPARTEMENT DE LA CHARENTE
# 996                         DEPARTEMENT DE LA CHARENTE
# 997  DEPARTEMENT DE LA CHARENTE - LABORATOIRE DEPAR...
# 998  DEPARTEMENT DE LA CHARENTE - LABORATOIRE DEPAR...
# 999  DEPARTEMENT DE LA CHARENTE - LABORATOIRE DEPAR...
#
# [1000 rows x 49 columns]
