# %%
import geopandas as gpd
import pandas as pd

# %%
hg=gpd.read_file("Hydroecoregion1-shp/Hydroecoregion1.shp")
dst = pd.read_csv("stations_hb.csv.zst", sep=';', escapechar='\\')
dhb= pd.read_csv("donnees_hydrobio.csv.zst", sep=',')
dpc = pd.read_csv('donnees_physicochimie.csv', nrows=1000)

# %%
chunksize = 1000

#list_of_dataframes = []

#for df in pd.read_csv('donnees_physicochimie.csv', chunksize=chunksize):
#    list_of_dataframes.append(df)

#result = pd.concat(list_of_dataframes)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#list_of_dataframes[0]

#Ou utiliser données plus petites
# Out:
#      CdStationMesureEauxSurface                   LbStationMesureEauxSurface  \
# 0                       5005600                  La Béronne en aval de Melle
# 1                       5200115           Le Laurhibar à Saint Jean le Vieux
# 2                       5001800  L'Arnoult en amont de Pont l'Abbé d'Arnoult
# 3                       5001800  L'Arnoult en amont de Pont l'Abbé d'Arnoult
# 4                       5001800  L'Arnoult en amont de Pont l'Abbé d'Arnoult
# ..                          ...                                          ...
# 995                     5011640           Le Condéon à Barbezieux St Hilaire
# 996                     5011640           Le Condéon à Barbezieux St Hilaire
# 997                     5011640           Le Condéon à Barbezieux St Hilaire
# 998                     5011640           Le Condéon à Barbezieux St Hilaire
# 999                     5011640           Le Condéon à Barbezieux St Hilaire
#
# ...

# %%
df_pc = reduced_df
# Out:
#      CdStationMesureEauxSurface                   LbStationMesureEauxSurface  \
# 0                       5005600                  La Béronne en aval de Melle
# 1                       5200115           Le Laurhibar à Saint Jean le Vieux
# 2                       5001800  L'Arnoult en amont de Pont l'Abbé d'Arnoult
# 3                       5001800  L'Arnoult en amont de Pont l'Abbé d'Arnoult
# 4                       5001800  L'Arnoult en amont de Pont l'Abbé d'Arnoult
# ..                          ...                                          ...
# 995                     5011640           Le Condéon à Barbezieux St Hilaire
# 996                     5011640           Le Condéon à Barbezieux St Hilaire
# 997                     5011640           Le Condéon à Barbezieux St Hilaire
# 998                     5011640           Le Condéon à Barbezieux St Hilaire
# 999                     5011640           Le Condéon à Barbezieux St Hilaire
#
# ...
